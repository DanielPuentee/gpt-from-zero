# %%
import sys
sys.path.append("../")
import torch

# Transformer Block
from src.components.transformer_block import TransformerBlock

# %% [markdown]
# **1. Parameters**

# %%
batch_size = 2
seq_len = 10
d_model = 128
n_heads = 4
d_ff = 512

# %% [markdown]
# **2. Embedding creation**
#
# *We create a random tensor to simulate the embeddings input to the attention mechanism.*

# %%
# Create input (from embeddings)
# 2 words / 8 tokens each / embedding size 128
x = torch.randn(batch_size, seq_len, d_model)
print(x.shape)
x[0]
# Out:
# torch.Size([2, 10, 128])
# tensor([[ 1.7692e+00, -1.3757e+00, -8.0366e-02,  ..., -1.2668e-03,
#          -3.7219e-01,  1.4542e-01],
#         [-1.5754e-01,  3.8314e-01, -2.5865e+00,  ..., -2.6758e+00,
#           1.9418e+00,  1.5100e-01],
#         [ 8.0297e-01,  6.5193e-01, -9.7989e-01,  ..., -1.8685e-01,
#           5.1058e-01, -3.1736e-01],
#         ...,
#         [ 1.8356e+00,  6.6542e-01,  7.2665e-01,  ...,  2.1823e+00,
#          -1.0555e+00, -4.0573e-01],
#         [ 7.1250e-01,  5.3970e-01, -6.1555e-01,  ...,  9.9330e-01,
#           9.2568e-01,  1.4920e+00],
#         [-1.9158e-01, -2.0013e+00,  1.6118e-01,  ...,  1.0841e+00,
#          -1.0669e+00, -1.1545e+00]])

# %% [markdown]
# **3. Transformer Block**

# %%
block = TransformerBlock(d_model, n_heads, d_ff)
out = block(x)
# Out:
# 2026-02-03 11:48:17.307 | DEBUG    | src.components.layer_norm:__init__:24 - LayerNorm: d_model=128, eps=1e-06
# 2026-02-03 11:48:17.308 | DEBUG    | src.components.layer_norm:__init__:24 - LayerNorm: d_model=128, eps=1e-06
# 2026-02-03 11:48:17.310 | DEBUG    | src.components.attention:__init__:54 - CausalSelfAttention: d_model=128, n_heads=4, head_dim=32, dropout=0.1
# 2026-02-03 11:48:17.314 | DEBUG    | src.components.feedforward:__init__:44 - FeedForward: d_model=128, d_ff=512, activation=gelu, dropout=0.1
# 2026-02-03 11:48:17.315 | DEBUG    | src.components.transformer_block:__init__:37 - TransformerBlock: d_model=128, n_heads=4, d_ff=512

# %%
out.shape
# Out:
# torch.Size([2, 10, 128])

# %% [markdown]
# <pre style="font-family: Menlo, Consolas, monospace; font-size: 14px; line-height: 1.35;">
# ┌──────────────────────────────────────────────┐
# │ Input                                        │
# │ (batch, seq, d_model)                        │
# └──────────────────────────────────────────────┘
#                     ↓
# ┌──────────────────────────────────────────────┐
# │ Layer Normalization                          │
# └──────────────────────────────────────────────┘
#                     ↓
# ┌──────────────────────────────────────────────┐
# │ Self-Attention                               │
# │ (causal masking applied here)                │
# └──────────────────────────────────────────────┘
#                     ↓
# ┌──────────────────────────────────────────────┐
# │ Residual Connection                          │
# │ Input + Attention Output                     │
# └──────────────────────────────────────────────┘
#                     ↓
# ┌──────────────────────────────────────────────┐
# │ Layer Normalization                          │
# └──────────────────────────────────────────────┘
#                     ↓
# ┌──────────────────────────────────────────────┐
# │ Feed-Forward Network                         │
# └──────────────────────────────────────────────┘
#                     ↓
# ┌──────────────────────────────────────────────┐
# │ Residual Connection                          │
# │ Attention Block Output + FFN Output           │
# └──────────────────────────────────────────────┘
#                     ↓
# ┌──────────────────────────────────────────────┐
# │ Output                                       │
# │ (batch, seq, d_model)                        │
# └──────────────────────────────────────────────┘
# </pre>

# %% [markdown]
# ---
